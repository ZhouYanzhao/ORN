# %%
# %matplotlib inline

# %%
import idx2numpy
import random
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import rotate
from scipy.misc import imresize

# %%
ndarr = idx2numpy.convert_from_file('/root/Cloud/ORN.caffe/examples/mnist/t.ubyte')
print(ndarr.shape)
# Out:
# (10000, 32, 32)

# %%
trans = rotate(imresize(ndarr[4], size=(32, 32), interp='bilinear'), random.randint(0, 360), reshape=False)
plt.imshow(trans)
print(trans.shape)
# Out:
# (32, 32)

# %%
arr = np.ndarray((ndarr.shape[0], 32, 32), dtype='uint8')
print(arr.dtype)
# Out:
# uint8

# %%
idx2numpy.convert_to_file('/root/Util/caffe/data/mnist/t10k-rot-images-idx3-ubyte', arr)
